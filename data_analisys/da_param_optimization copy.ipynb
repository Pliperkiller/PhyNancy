# %%
import psycopg2
import pandas as pd
import sys
import os
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import scipy.stats as stats
import pytz
import pandas_ta as ta
import plotly.express as px
import plotly.graph_objects as go
import itertools
import random
from da_controller import *
from strategies import *
from sklearn.model_selection import GridSearchCV
from sklearn.base import BaseEstimator
from typing import Dict, List, Any
from optimizers import GeneticOptimizer, GridSearchOptimizer

controllers_path = os.path.abspath("../historic_updater")
sys.path.append(controllers_path)
from controllers import *

# READ DF
data_path = os.path.abspath("../data")
sys.path.append(data_path)
file_name = 'BTCUSDT_futures_5m_2024-01-01_2024-12-31.csv'
data_filepath = os.path.join(data_path, file_name)
df = pd.read_csv(data_filepath)
df = format_df(df)
df = df.reset_index(drop=True)

# %%
# Calcular indicadores
df = EMADXRSI_scalping_strategy(df, long_EMA=50, trend_range = 50, trend_theshold = 0.5,
                                support_range=50, support_chance=0.75,
                                 ADX_thresh=30, ADX_period=5, 
                                 RSI_period=3, RSI_overbought=80, RSI_oversold=20,
                                 vol_sma_period=20, max_wait=5)
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\pipek\Documents\codefolder\nancy\PhyNancy\venv\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'wait_time_red'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[4], line 2
#       1 # Calcular indicadores
# ...

# %%
buy_signals = df[df['Buy_Signal']]
buy_signals
# Out:
#                open_time     open     high      low    close      volume  \
# 142  2023-01-24 19:00:00  22627.5  22699.0  22310.5  22641.0   97898.966
# 483  2023-03-22 15:00:00  26653.3  27425.3  26590.0  27233.8  168601.777
# 1797 2023-10-27 15:00:00  33705.6  33948.9  33686.0  33893.1   24414.268
# 1837 2023-11-03 07:00:00  34265.5  34850.0  34155.4  34759.5   74192.851
# 1861 2023-11-07 07:00:00  34633.3  34849.4  34520.3  34728.4   43458.375
# 1901 2023-11-13 23:00:00  36473.1  36740.8  36404.8  36705.5   21584.608
# 1977 2023-11-26 15:00:00  37360.1  37744.9  37306.5  37437.9   46009.013
#
#                   close_time  quote_asset_volume  number_of_trades  \
# 142  2023-01-24 22:59:59.999        2.206165e+09            583995
# 483  2023-03-22 18:59:59.999        4.570693e+09           1424626
# 1797 2023-10-27 18:59:59.999        8.258272e+08            341072
# 1837 2023-11-03 10:59:59.999        2.564325e+09            785379
# ...
